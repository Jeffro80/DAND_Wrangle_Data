# %% [markdown]
# ### Introduction

# %% [markdown]
# WeRateDogs is a Twitter handle that provide humorous tweets rating photos of dogs. The archive of the WeRateDogs Twitter handle was examined to look for any trends in the popularity of dogs based on dog type and dog style.

# %% [markdown]
# ### Questions

# %% [markdown]
# The investigation set out to discover which dog types and dog styles were most popular based on their ratings, retweet count and favorite count. The specific questions that were investigated were as follows:
#
# - What type of dogs have the highest ratings?
# - What type of dogs are the most popular in terms of retweet count and favorite count?
# - What dog stage has the highest ratings?

# %% [markdown]
# ### Findings

# %% [markdown]
# The analysis of the data showed some interesting results. The most popular dog types (by number of tweets) also tended to have the highest retweet and favorite counts. Here **Golden Retrievers**, **Labrador Retrievers** and **Pembrokes** had the highest counts for retweets and favorite counts.
#
# Several of the dog types that scored highest by average counts for retweet and favorite counts had very small tweet counts (less than 5) which skewed their results. **Eskimo Dogs** stood out as having a reasonable number of samples (9) and still averaging well. **French Bulldogs** did well for favorite counts with a fair number of samples (29) and **Samoyeds** did well on retweet counts with the same number of samples.
#
# Dog stages were also identified from the tweet text and used for analysis. Only a subset of the tweets were able to be accurately identified for dog style. The most popular dog stage (by tweets) was the pupper which had more than the other categories combined. It led in the counts totals for retweets and favorites, as expected, but based on averages the **doggo** was highest for retweets and **puppo** was highest for favorites. For ratings, the averages were very close with only 0.13 separating the highest rated dog style from the lowest.

# %% [markdown]
# The two graphs below show that Average Retweet Count and Average Favorite Count by dog stage showed a general pattern of the dog stages falling in the following order (most popular to least popular):
#
# - puppo
# - doggo
# - mixed
# - floofer
# - pupper

# %% [markdown]
# ![avg_retweet_counts.png](attachment:avg_retweet_counts.png)

# %% [markdown]
# ![avg_favorite_counts.png](attachment:avg_favorite_counts.png)

# %% [markdown]
# ### Discussion and Conclusion

# %% [markdown]
# The dog type was identified through artificial intelligence, with a prediction confidence of 0.5 being required for the dog type to be accepted. There were 100 different types of dogs identified - using broader groupings would have reduced this number and made the analysis a bit more accurate (higher sample numbers per dog type), however, it would also make the findings more generalized.
#
# **Golden Retrievers**, **Labrador Retrievers** and **Pembrokes** were some of the most popular in terms of their number of retweets, which was also reflected in their retweet and favorite counts. **Puppo** and **Doggo** were the most popular dog styles, however, the majority of tweets were not able to have their dog style identified.
#
# Based on this analysis it appears that people like a range of dog types and styles, with retrievers being among the most popular dog type and puppos and doggos being the most popular styles.
